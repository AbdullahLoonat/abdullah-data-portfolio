# %%
https://www.espncricinfo.com/records/highest-career-batting-average-282910

# %%
#import pandas as pd

# %%
import pandas as pd

# %%
#import csv

# %%
df = pd.read_csv('crickettestmatchdata.csv')

# %%
df
# Out:
#                         Player       Span  Mat  Inns  NO  Runs    HS    Ave  \
# 0             DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94
# 1             PHKD Mendis (SL)  2022-2025   14    24   3  1316  182*  62.66
# 2               AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87
# 3              RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97
# 4              GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83
# ..                         ...        ...  ...   ...  ..   ...   ...    ...
# 60           GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25
# 61           WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22
# 62             SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21
# 63  Hashmatullah Shahidi (AFG)  2018-2025   11    21   5   771   246  48.18
# 64            DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00
#
#        BF     SR  100  50   0    4s  6s  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0   9800+   58.6   29  13   7  626+   6          NaN          NaN          NaN
# 1    2063  63.79    5   5   0   137  24          NaN          NaN          NaN
# 2    2667  55.68    5   4   2   186   5          NaN          NaN          NaN
# 3   1707+  54.48    7  11   1  246+  11          NaN          NaN          NaN
# 4    416+     56   10   5   2  104+   1          NaN          NaN          NaN
# ..    ...    ...  ...  ..  ..   ...  ..          ...          ...          ...
# 60  15525  59.67   27  38  11  1165  24          NaN          NaN          NaN
# 61  3118+  44.77    7   6   1  119+   0          NaN          NaN          NaN
# 62  3217+  60.02    6  13   4  241+  5+          NaN          NaN          NaN
# 63   1629  47.32    2   2   0    87   1          NaN          NaN          NaN
# 64  2110+  25.59    1  10   2   53+   0          NaN          NaN          NaN
#
# [65 rows x 18 columns]

# %%
#rename muliple colums in a list

# %%
df = df.rename(columns = {'Mat':'Matches_Played','NO':'Not_Out','HS':'Highest_Inns_Score','Inns':'Innings_Batted','BF':'Balls_Faced','SR':'Batting_Strike_Rate'})

# %%
df.head()
# Out:
#              Player       Span  Matches_Played  Innings_Batted  Not_Out  Runs  \
# 0  DG Bradman (AUS)  1928-1948              52              80       10  6996
# 1  PHKD Mendis (SL)  2022-2025              14              24        3  1316
# 2    AC Voges (AUS)  2015-2016              20              31        7  1485
# 3   RG Pollock (SA)  1963-1970              23              41        4  2256
# 4   GA Headley (WI)  1930-1954              22              40        4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate  100  50  0    4s  \
# 0                334  99.94       9800+                58.6   29  13  7  626+
# 1               182*  62.66        2063               63.79    5   5  0   137
# 2               269*  61.87        2667               55.68    5   4  2   186
# 3                274  60.97       1707+               54.48    7  11  1  246+
# 4               270*  60.83        416+                  56   10   5  2  104+
#
#    6s  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0   6          NaN          NaN          NaN
# 1  24          NaN          NaN          NaN
# 2   5          NaN          NaN          NaN
# 3  11          NaN          NaN          NaN
# 4   1          NaN          NaN          NaN

# %%
#check null values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches_Played         False
# Innings_Batted         False
# Not_Out                False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Unnamed: 15             True
# Unnamed: 16             True
# Unnamed: 17             True
# dtype: bool

# %%
df = df.drop(['Unnamed: 15','Unnamed: 16','Unnamed: 17'], axis = 1)

# %%
df.head()
# Out:
#              Player       Span  Matches_Played  Innings_Batted  Not_Out  Runs  \
# 0  DG Bradman (AUS)  1928-1948              52              80       10  6996
# 1  PHKD Mendis (SL)  2022-2025              14              24        3  1316
# 2    AC Voges (AUS)  2015-2016              20              31        7  1485
# 3   RG Pollock (SA)  1963-1970              23              41        4  2256
# 4   GA Headley (WI)  1930-1954              22              40        4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate  100  50  0    4s  \
# 0                334  99.94       9800+                58.6   29  13  7  626+
# 1               182*  62.66        2063               63.79    5   5  0   137
# 2               269*  61.87        2667               55.68    5   4  2   186
# 3                274  60.97       1707+               54.48    7  11  1  246+
# 4               270*  60.83        416+                  56   10   5  2  104+
#
#    6s
# 0   6
# 1  24
# 2   5
# 3  11
# 4   1

# %%
#drop duplications

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 65, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#              Player       Span  Matches_Played  Innings_Batted  Not_Out  Runs  \
# 5   GA Headley (WI)  1930-1954              22              40        4  2190
# 12   GS Sobers (WI)  1954-1974              93             160       21  8032
# 15   JB Hobbs (ENG)  1908-1930              61             102        7  5410
#
#    Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate  100  50   0  \
# 5                270*  60.83        416+                  56   10   5   2
# 12               365*  57.78       4063+               53.58   26  30  12
# 15                211  56.94       5363+               46.22   15  28   4
#
#       4s   6s  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 5   104+    1          NaN          NaN          NaN
# 12  593+  32+          NaN          NaN          NaN
# 15  276+    8          NaN          NaN          NaN

# %%
df[df['Player'].isin(['GA Headley (WI)','GS Sobers (WI)','JB Hobbs (ENG)'])]
# Out:
#              Player       Span  Matches_Played  Innings_Batted  Not_Out  Runs  \
# 4   GA Headley (WI)  1930-1954              22              40        4  2190
# 5   GA Headley (WI)  1930-1954              22              40        4  2190
# 11   GS Sobers (WI)  1954-1974              93             160       21  8032
# 12   GS Sobers (WI)  1954-1974              93             160       21  8032
# 14   JB Hobbs (ENG)  1908-1930              61             102        7  5410
# 15   JB Hobbs (ENG)  1908-1930              61             102        7  5410
#
#    Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate  100  50   0  \
# 4                270*  60.83        416+                  56   10   5   2
# 5                270*  60.83        416+                  56   10   5   2
# 11               365*  57.78       4063+               53.58   26  30  12
# 12               365*  57.78       4063+               53.58   26  30  12
# 14                211  56.94       5363+               46.22   15  28   4
# 15                211  56.94       5363+               46.22   15  28   4
#
#       4s   6s  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 4   104+    1          NaN          NaN          NaN
# 5   104+    1          NaN          NaN          NaN
# 11  593+  32+          NaN          NaN          NaN
# 12  593+  32+          NaN          NaN          NaN
# 14  276+    8          NaN          NaN          NaN
# 15  276+    8          NaN          NaN          NaN

# %%
df = df.drop_duplicates()

# %%
#split up sapn into start and end date + career length

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2025]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 60    [2002, 2014]
# 61    [1924, 1934]
# 62    [1930, 1938]
# 63    [2018, 2025]
# 64    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat = '-').str[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
#       ...
# 60    2002
# 61    1924
# 62    1930
# 63    2018
# 64    1928
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie_year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['final_year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                         Player       Span  Matches_Played  Innings_Batted  \
# 0             DG Bradman (AUS)  1928-1948              52              80
# 1             PHKD Mendis (SL)  2022-2025              14              24
# 2               AC Voges (AUS)  2015-2016              20              31
# 3              RG Pollock (SA)  1963-1970              23              41
# 4              GA Headley (WI)  1930-1954              22              40
# ..                         ...        ...             ...             ...
# 60           GC Smith (ICC/SA)  2002-2014             117             205
# 61           WH Ponsford (AUS)  1924-1934              29              48
# 62             SJ McCabe (AUS)  1930-1938              39              62
# 63  Hashmatullah Shahidi (AFG)  2018-2025              11              21
# 64            DR Jardine (ENG)  1928-1934              22              33
#
#     Not_Out  Runs Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate  \
# 0        10  6996                334  99.94       9800+                58.6
# 1         3  1316               182*  62.66        2063               63.79
# 2         7  1485               269*  61.87        2667               55.68
# 3         4  2256                274  60.97       1707+               54.48
# 4         4  2190               270*  60.83        416+                  56
# ..      ...   ...                ...    ...         ...                 ...
# 60       13  9265                277  48.25       15525               59.67
# 61        4  2122                266  48.22       3118+               44.77
# 62        5  2748                232  48.21       3217+               60.02
# 63        5   771                246  48.18        1629               47.32
# 64        6  1296                127  48.00       2110+               25.59
#
#     100  50   0    4s  6s Rookie-year final_year Rookie_year
# 0    29  13   7  626+   6        1928       1948        1928
# 1     5   5   0   137  24        2022       2025        2022
# 2     5   4   2   186   5        2015       2016        2015
# 3     7  11   1  246+  11        1963       1970        1963
# 4    10   5   2  104+   1        1930       1954        1930
# ..  ...  ..  ..   ...  ..         ...        ...         ...
# 60   27  38  11  1165  24        2002       2014        2002
# 61    7   6   1  119+   0        1924       1934        1924
# 62    6  13   4  241+  5+        1930       1938        1930
# 63    2   2   0    87   1        2018       2025        2018
# 64    1  10   2   53+   0        1928       1934        1928
#
# [62 rows x 18 columns]

# %%
#drop span colums

# %%
df = df.drop(['Span','Rookie-year'], axis = 1)

# %%
df.head()
# Out:
#              Player  Matches_Played  Innings_Batted  Not_Out  Runs  \
# 0  DG Bradman (AUS)              52              80       10  6996
# 1  PHKD Mendis (SL)              14              24        3  1316
# 2    AC Voges (AUS)              20              31        7  1485
# 3   RG Pollock (SA)              23              41        4  2256
# 4   GA Headley (WI)              22              40        4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate  100  50  0    4s  \
# 0                334  99.94       9800+                58.6   29  13  7  626+
# 1               182*  62.66        2063               63.79    5   5  0   137
# 2               269*  61.87        2667               55.68    5   4  2   186
# 3                274  60.97       1707+               54.48    7  11  1  246+
# 4               270*  60.83        416+                  56   10   5  2  104+
#
#    6s final_year Rookie_year
# 0   6       1948        1928
# 1  24       2025        2022
# 2   5       2016        2015
# 3  11       1970        1963
# 4   1       1954        1930

# %%
#split up the country from player

# %%
df['Player'].str.split(pat = '(').str[1]
# Out:
# 0        AUS)
# 1         SL)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 60    ICC/SA)
# 61       AUS)
# 62       AUS)
# 63       AFG)
# 64       ENG)
# Name: Player, Length: 62, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Player_name'] = df['Player'].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#              Player  Matches_Played  Innings_Batted  Not_Out  Runs  \
# 0  DG Bradman (AUS)              52              80       10  6996
# 1  PHKD Mendis (SL)              14              24        3  1316
# 2    AC Voges (AUS)              20              31        7  1485
# 3   RG Pollock (SA)              23              41        4  2256
# 4   GA Headley (WI)              22              40        4  2190
#
#   Highest_Inns_Score    Ave Balls_Faced Batting_Strike_Rate  100  50  0    4s  \
# 0                334  99.94       9800+                58.6   29  13  7  626+
# 1               182*  62.66        2063               63.79    5   5  0   137
# 2               269*  61.87        2667               55.68    5   4  2   186
# 3                274  60.97       1707+               54.48    7  11  1  246+
# 4               270*  60.83        416+                  56   10   5  2  104+
#
#    6s final_year Rookie_year Country   Player_name
# 0   6       1948        1928    AUS)   DG Bradman
# 1  24       2025        2022     SL)  PHKD Mendis
# 2   5       2016        2015    AUS)     AC Voges
# 3  11       1970        1963     SA)   RG Pollock
# 4   1       1954        1930     WI)   GA Headley

# %%
df = df.drop(['Player'], axis = 1)

# %%
df
# Out:
#     Matches_Played  Innings_Batted  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0               52              80       10  6996                334  99.94
# 1               14              24        3  1316               182*  62.66
# 2               20              31        7  1485               269*  61.87
# 3               23              41        4  2256                274  60.97
# 4               22              40        4  2190               270*  60.83
# ..             ...             ...      ...   ...                ...    ...
# 60             117             205       13  9265                277  48.25
# 61              29              48        4  2122                266  48.22
# 62              39              62        5  2748                232  48.21
# 63              11              21        5   771                246  48.18
# 64              22              33        6  1296                127  48.00
#
#    Balls_Faced Batting_Strike_Rate  100  50   0    4s  6s final_year  \
# 0        9800+                58.6   29  13   7  626+   6       1948
# 1         2063               63.79    5   5   0   137  24       2025
# 2         2667               55.68    5   4   2   186   5       2016
# 3        1707+               54.48    7  11   1  246+  11       1970
# 4         416+                  56   10   5   2  104+   1       1954
# ..         ...                 ...  ...  ..  ..   ...  ..        ...
# 60       15525               59.67   27  38  11  1165  24       2014
# 61       3118+               44.77    7   6   1  119+   0       1934
# 62       3217+               60.02    6  13   4  241+  5+       1938
# 63        1629               47.32    2   2   0    87   1       2025
# 64       2110+               25.59    1  10   2   53+   0       1934
#
#    Rookie_year  Country            Player_name
# 0         1928     AUS)            DG Bradman
# 1         2022      SL)           PHKD Mendis
# 2         2015     AUS)              AC Voges
# 3         1963      SA)            RG Pollock
# 4         1930      WI)            GA Headley
# ..         ...      ...                    ...
# 60        2002  ICC/SA)              GC Smith
# 61        1924     AUS)           WH Ponsford
# 62        1930     AUS)             SJ McCabe
# 63        2018     AFG)  Hashmatullah Shahidi
# 64        1928     ENG)            DR Jardine
#
# [62 rows x 17 columns]

# %%
df['Country'].str.split(pat = '(').str[0]
# Out:
# 0        AUS)
# 1         SL)
# 2        AUS)
# 3         SA)
# 4         WI)
#        ...
# 60    ICC/SA)
# 61       AUS)
# 62       AUS)
# 63       AFG)
# 64       ENG)
# Name: Country, Length: 62, dtype: object

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1         SL
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 60    ICC/SA
# 61       AUS
# 62       AUS
# 63       AFG
# 64       ENG
# Name: Country, Length: 62, dtype: object

# %%
df
# Out:
#     Matches_Played  Innings_Batted  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0               52              80       10  6996                334  99.94
# 1               14              24        3  1316               182*  62.66
# 2               20              31        7  1485               269*  61.87
# 3               23              41        4  2256                274  60.97
# 4               22              40        4  2190               270*  60.83
# ..             ...             ...      ...   ...                ...    ...
# 60             117             205       13  9265                277  48.25
# 61              29              48        4  2122                266  48.22
# 62              39              62        5  2748                232  48.21
# 63              11              21        5   771                246  48.18
# 64              22              33        6  1296                127  48.00
#
#    Balls_Faced Batting_Strike_Rate  100  50   0    4s  6s final_year  \
# 0        9800+                58.6   29  13   7  626+   6       1948
# 1         2063               63.79    5   5   0   137  24       2025
# 2         2667               55.68    5   4   2   186   5       2016
# 3        1707+               54.48    7  11   1  246+  11       1970
# 4         416+                  56   10   5   2  104+   1       1954
# ..         ...                 ...  ...  ..  ..   ...  ..        ...
# 60       15525               59.67   27  38  11  1165  24       2014
# 61       3118+               44.77    7   6   1  119+   0       1934
# 62       3217+               60.02    6  13   4  241+  5+       1938
# 63        1629               47.32    2   2   0    87   1       2025
# 64       2110+               25.59    1  10   2   53+   0       1934
#
#    Rookie_year Country            Player_name
# 0         1928     AUS            DG Bradman
# 1         2022      SL           PHKD Mendis
# 2         2015     AUS              AC Voges
# 3         1963      SA            RG Pollock
# 4         1930      WI            GA Headley
# ..         ...     ...                    ...
# 60        2002  ICC/SA              GC Smith
# 61        1924     AUS           WH Ponsford
# 62        1930     AUS             SJ McCabe
# 63        2018     AFG  Hashmatullah Shahidi
# 64        1928     ENG            DR Jardine
#
# [62 rows x 17 columns]

# %%
#change datatypes

# %%
df.dtypes
# Out:
# Matches_Played           int64
# Innings_Batted           int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate     object
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# final_year              object
# Rookie_year             object
# Country                 object
# Player_name             object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat = '*')
# Out:
# 0       [334]
# 1     [182, ]
# 2     [269, ]
# 3       [274]
# 4     [270, ]
#        ...
# 60      [277]
# 61      [266]
# 62      [232]
# 63      [246]
# 64      [127]
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     182
# 2     269
# 3     274
# 4     270
#      ...
# 60    277
# 61    266
# 62    232
# 63    246
# 64    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df
# Out:
#     Matches_Played  Innings_Batted  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0               52              80       10  6996                334  99.94
# 1               14              24        3  1316                182  62.66
# 2               20              31        7  1485                269  61.87
# 3               23              41        4  2256                274  60.97
# 4               22              40        4  2190                270  60.83
# ..             ...             ...      ...   ...                ...    ...
# 60             117             205       13  9265                277  48.25
# 61              29              48        4  2122                266  48.22
# 62              39              62        5  2748                232  48.21
# 63              11              21        5   771                246  48.18
# 64              22              33        6  1296                127  48.00
#
#    Balls_Faced Batting_Strike_Rate  100  50   0    4s  6s final_year  \
# 0        9800+                58.6   29  13   7  626+   6       1948
# 1         2063               63.79    5   5   0   137  24       2025
# 2         2667               55.68    5   4   2   186   5       2016
# 3        1707+               54.48    7  11   1  246+  11       1970
# 4         416+                  56   10   5   2  104+   1       1954
# ..         ...                 ...  ...  ..  ..   ...  ..        ...
# 60       15525               59.67   27  38  11  1165  24       2014
# 61       3118+               44.77    7   6   1  119+   0       1934
# 62       3217+               60.02    6  13   4  241+  5+       1938
# 63        1629               47.32    2   2   0    87   1       2025
# 64       2110+               25.59    1  10   2   53+   0       1934
#
#    Rookie_year Country            Player_name
# 0         1928     AUS            DG Bradman
# 1         2022      SL           PHKD Mendis
# 2         2015     AUS              AC Voges
# 3         1963      SA            RG Pollock
# 4         1930      WI            GA Headley
# ..         ...     ...                    ...
# 60        2002  ICC/SA              GC Smith
# 61        1924     AUS           WH Ponsford
# 62        1930     AUS             SJ McCabe
# 63        2018     AFG  Hashmatullah Shahidi
# 64        1928     ENG            DR Jardine
#
# [62 rows x 17 columns]

# %%
df['Highest_Inns_Score'].astype('int')

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Matches_Played           int64
# Innings_Batted           int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate     object
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# final_year              object
# Rookie_year             object
# Country                 object
# Player_name             object
# dtype: object

# %%
df = df.astype({'final_year':'int','Rookie_year':'int'})

# %%
df.dtypes
# Out:
# Matches_Played           int64
# Innings_Batted           int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate     object
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# final_year               int64
# Rookie_year              int64
# Country                 object
# Player_name             object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 df['Balls_Faced'] = df['Balls_Faced'].astype('int')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '-'

# %%
df[df'Balls_Faced'].isna()==1
# Out:
#   Cell In[65], line 1
#     df[df'Balls_Faced'].isna()==1
#          ^
# SyntaxError: invalid syntax

# %%
df[df'Balls_Faced'].isna('-')==1
# Out:
#   Cell In[66], line 1
#     df[df'Balls_Faced'].isna('-')==1
#          ^
# SyntaxError: invalid syntax

# %%
df['Balls_Faced'] = (
    df['Balls_Faced']
    .astype(str)
    .str.strip()
    .replace('-', '0')
)

df['Balls_Faced'] = df['Balls_Faced'].astype(int)

# %%
df.dtypes
# Out:
# Matches_Played           int64
# Innings_Batted           int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate     object
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# final_year               int64
# Rookie_year              int64
# Country                 object
# Player_name             object
# dtype: object

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].astype('float')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
df['Batting_Strike_Rate'] = (
    df['Batting_Strike_Rate']
    .astype(str)
    .str.strip()
    .replace('-', '0')
)

df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].astype(float)

# %%
df.dtypes
# Out:
# Matches_Played           int64
# Innings_Batted           int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# final_year               int64
# Rookie_year              int64
# Country                 object
# Player_name             object
# dtype: object

# %%
df = df.astype({'4s':'int','6s':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df = df.astype({'4s':'int','6s':'int'})
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6642, in NDFrame.astype(self, dtype, copy, errors)
#    6640 else:
#    6641     try:
# -> 6642         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6643     except ValueError as ex:
#    6644         ex.args = (
#    6645             f"{ex}: Error while type casting for column '{col_name}'",
#    6646         )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:449, in BaseBlockManager.astype(self, dtype, copy, errors)
#     446 elif using_copy_on_write():
#     447     copy = False
# --> 449 return self.apply(
#     450     "astype",
#     451     dtype=dtype,
#     452     copy=copy,
#     453     errors=errors,
#     454     using_cow=using_copy_on_write(),
#     455 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:784, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     781         raise ValueError("Can not squeeze with more than one column.")
#     782     values = values[0, :]  # type: ignore[call-overload]
# --> 784 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     786 new_values = maybe_coerce_values(new_values)
#     788 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '626+': Error while type casting for column '4s'

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[0]

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
df['4s'] = df['4s'].astype('int')

# %%
df['6s'] = df['6s'].astype('int')

# %%
df.dtypes
# Out:
# Matches_Played           int64
# Innings_Batted           int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# final_year               int64
# Rookie_year              int64
# Country                 object
# Player_name             object
# dtype: object

# %%
df
# Out:
#     Matches_Played  Innings_Batted  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 0               52              80       10  6996                 334  99.94
# 1               14              24        3  1316                 182  62.66
# 2               20              31        7  1485                 269  61.87
# 3               23              41        4  2256                 274  60.97
# 4               22              40        4  2190                 270  60.83
# ..             ...             ...      ...   ...                 ...    ...
# 60             117             205       13  9265                 277  48.25
# 61              29              48        4  2122                 266  48.22
# 62              39              62        5  2748                 232  48.21
# 63              11              21        5   771                 246  48.18
# 64              22              33        6  1296                 127  48.00
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  final_year  \
# 0          9800                58.60   29  13   7   626   6        1948
# 1          2063                63.79    5   5   0   137  24        2025
# 2          2667                55.68    5   4   2   186   5        2016
# 3          1707                54.48    7  11   1   246  11        1970
# 4           416                56.00   10   5   2   104   1        1954
# ..          ...                  ...  ...  ..  ..   ...  ..         ...
# 60        15525                59.67   27  38  11  1165  24        2014
# 61         3118                44.77    7   6   1   119   0        1934
# 62         3217                60.02    6  13   4   241   5        1938
# 63         1629                47.32    2   2   0    87   1        2025
# 64         2110                25.59    1  10   2    53   0        1934
#
#     Rookie_year Country            Player_name
# 0          1928     AUS            DG Bradman
# 1          2022      SL           PHKD Mendis
# 2          2015     AUS              AC Voges
# 3          1963      SA            RG Pollock
# 4          1930      WI            GA Headley
# ..          ...     ...                    ...
# 60         2002  ICC/SA              GC Smith
# 61         1924     AUS           WH Ponsford
# 62         1930     AUS             SJ McCabe
# 63         2018     AFG  Hashmatullah Shahidi
# 64         1928     ENG            DR Jardine
#
# [62 rows x 17 columns]

# %%
#career lenghth colum how log a playeer played

# %%
df['Career_Length'] = df['final_year'] - df['Rookie_year']

# %%
df
# Out:
#     Matches_Played  Innings_Batted  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 0               52              80       10  6996                 334  99.94
# 1               14              24        3  1316                 182  62.66
# 2               20              31        7  1485                 269  61.87
# 3               23              41        4  2256                 274  60.97
# 4               22              40        4  2190                 270  60.83
# ..             ...             ...      ...   ...                 ...    ...
# 60             117             205       13  9265                 277  48.25
# 61              29              48        4  2122                 266  48.22
# 62              39              62        5  2748                 232  48.21
# 63              11              21        5   771                 246  48.18
# 64              22              33        6  1296                 127  48.00
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  final_year  \
# 0          9800                58.60   29  13   7   626   6        1948
# 1          2063                63.79    5   5   0   137  24        2025
# 2          2667                55.68    5   4   2   186   5        2016
# 3          1707                54.48    7  11   1   246  11        1970
# 4           416                56.00   10   5   2   104   1        1954
# ..          ...                  ...  ...  ..  ..   ...  ..         ...
# 60        15525                59.67   27  38  11  1165  24        2014
# 61         3118                44.77    7   6   1   119   0        1934
# 62         3217                60.02    6  13   4   241   5        1938
# 63         1629                47.32    2   2   0    87   1        2025
# 64         2110                25.59    1  10   2    53   0        1934
#
#     Rookie_year Country            Player_name  Career_Length
# 0          1928     AUS            DG Bradman              20
# 1          2022      SL           PHKD Mendis               3
# 2          2015     AUS              AC Voges               1
# 3          1963      SA            RG Pollock               7
# 4          1930      WI            GA Headley              24
# ..          ...     ...                    ...            ...
# 60         2002  ICC/SA              GC Smith              12
# 61         1924     AUS           WH Ponsford              10
# 62         1930     AUS             SJ McCabe               8
# 63         2018     AFG  Hashmatullah Shahidi               7
# 64         1928     ENG            DR Jardine               6
#
# [62 rows x 18 columns]

# %%
#average career length

# %%
df['Career_Length'].mean()
# Out:
# np.float64(13.129032258064516)

# %%
import numpy as np

value = np.float64(13.129032258064516)

print(round(value, 2))
# Out:
# 13.13

# %%
#average batting strike rate for cricketers who played over 10 years

# %%
df[df['Career_Length'] > 10 ]
# Out:
#     Matches_Played  Innings_Batted  Not_Out   Runs  Highest_Inns_Score    Ave  \
# 0               52              80       10   6996                 334  99.94
# 4               22              40        4   2190                 270  60.83
# 6               54              84        9   4555                 194  60.73
# 8               82             131       15   6806                 256  58.67
# 10              85             140       16   7249                 336  58.45
# 11              93             160       21   8032                 365  57.78
# 13             134             233       17  12400                 319  57.40
# 14              61             102        7   5410                 211  56.94
# 16              44              74        7   3798                 220  56.68
# 17              79             138       15   6971                 364  56.67
# 18             123             220       28  10763                 239  56.05
# 19             166             280       40  13289                 224  55.37
# 22             108             192       19   9461                 251  54.68
# 25              87             151       19   7110                 247  53.86
# 26              34              62        7   2960                 231  53.81
# 27             200             329       33  15921                 248  53.78
# 28             131             232        6  11953                 400  52.88
# 29             124             189       21   8832                 280  52.57
# 30             164             286       32  13288                 270  52.31
# 31              90             156       12   7530                 223  52.29
# 32             118             213       19  10099                 313  52.05
# 33             168             287       29  13378                 257  51.85
# 37             164             280       49  11867                 203  51.37
# 38             125             214       16  10122                 236  51.12
# 39             163             298       25  13943                 262  51.07
# 40             168             260       46  10927                 200  51.06
# 41             103             184       14   8625                 380  50.73
# 42             114             191       18   8765                 278  50.66
# 43             156             265       44  11174                 205  50.56
# 44             121             182       12   8540                 291  50.23
# 45              78             131       15   5807                 278  50.06
# 46             149             252       15  11814                 374  49.84
# 47             120             200       22   8830                 329  49.60
# 48              51              87        9   3860                 261  49.48
# 49              17              26        2   1185                 182  49.37
# 50             104             180        6   8586                 319  49.34
# 53             115             198       22   8643                 329  49.10
# 55              42              80        9   3471                 189  48.88
# 56              20              33        4   1415                 144  48.79
# 57              81             132       20   5462                 231  48.76
# 58              79             137       10   6149                 205  48.41
# 59              74             125       14   5357                 250  48.26
# 60             117             205       13   9265                 277  48.25
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  final_year  \
# 0          9800                58.60   29  13   7   626   6        1948
# 4           416                56.00   10   5   2   104   1        1954
# 6          6558                34.59   16  23   2   202   6        1935
# 8          4957                42.42   20  35   5   591  27        1968
# 10         7491                38.07   22  24   4   419  27        1947
# 11         4063                53.58   26  30  12   593  32        1974
# 13        22882                54.19   38  52  11  1491  51        2015
# 14         5363                46.22   15  28   4   276   8        1930
# 16            0                 0.00   15  14   1   107  11        1960
# 17         2844                39.34   19  33   5   358   7        1955
# 18        19966                53.90   37  44  11  1172  67        2026
# 19        28903                45.97   45  58  16  1488  97        2013
# 22        18198                51.98   33  38  11  1056  28        2025
# 25        13079                51.53   24  31  12   755  16        1984
# 26          108                63.88    9  14   3   115   6        1951
# 27        29437                54.04   51  68  14  2058  69        2013
# 28        19753                60.51   34  48  17  1559  88        2006
# 29        15164                45.99   23  43   6   788  48        1993
# 30        31258                42.51   36  63   8  1654  21        2012
# 31        14372                52.39   24  33  11   957  51        2010
# 32        19375                52.12   34  33  19  1082  70        2017
# 33        22782                58.72   41  62  17  1509  73        2012
# 37        27395                43.31   30  66  15  1285  36        2015
# 38        14184                43.35   34  45  12   908  26        1987
# 39        24242                57.51   41  66  15  1492  46        2026
# 40        22461                48.64   32  50  22  1175  20        2004
# 41        14349                60.10   30  29  14  1049  82        2009
# 42        16077                54.51   22  46   8  1024  64        2018
# 43        27002                41.09   27  63  11  1161  28        1994
# 44         9613                69.77   24  45  10   952  84        1991
# 45         2731                38.81   17  28  10   342   3        1957
# 46        22959                51.45   34  50  15  1387  61        2014
# 47        16345                54.02   25  46  15  1105  48        2007
# 48          488                40.16    9  22  11   240  11        1963
# 49          619                30.04    4   3   3    38   0        1928
# 50        10441                82.23   23  32  16  1233  91        2013
# 53        15456                55.92   28  27   9   978  39        2015
# 55          158                29.11    8  21   3    41   1        1949
# 56            0                 0.00    5   6   3    51   0        1905
# 57        11641                46.92   14  30  11   633   7        2013
# 58         1799                43.74   21  24   7   427   1        1963
# 59         8662                49.16   15  33   4   525  23        1981
# 60        15525                59.67   27  38  11  1165  24        2014
#
#     Rookie_year  Country        Player_name  Career_Length
# 0          1928      AUS        DG Bradman              20
# 4          1930       WI        GA Headley              24
# 6          1924      ENG       H Sutcliffe              11
# 8          1955      ENG     KF Barrington              13
# 10         1927      ENG        WR Hammond              20
# 11         1954       WI         GS Sobers              20
# 13         2000       SL     KC Sangakkara              15
# 14         1908      ENG          JB Hobbs              22
# 16         1948       WI        CL Walcott              12
# 17         1937      ENG          L Hutton              18
# 18         2010      AUS         SPD Smith              16
# 19         1995   ICC/SA         JH Kallis              18
# 22         2010       NZ     KS Williamson              15
# 25         1970      AUS       GS Chappell              14
# 26         1935       SA         AD Nourse              16
# 27         1989      IND      SR Tendulkar              24
# 28         1990   ICC/WI           BC Lara              16
# 29         1976      PAK     Javed Miandad              17
# 30         1996  ICC/IND          R Dravid              16
# 31         1998      PAK   Mohammad Yousuf              12
# 32         2000      PAK       Younis Khan              17
# 33         1995      AUS        RT Ponting              17
# 37         1994       WI     S Chanderpaul              21
# 38         1971      IND       SM Gavaskar              16
# 39         2012      ENG           JE Root              14
# 40         1985      AUS          SR Waugh              19
# 41         1994      AUS         ML Hayden              15
# 42         2004       SA    AB de Villiers              14
# 43         1978      AUS         AR Border              16
# 44         1974       WI      IVA Richards              17
# 45         1937      ENG       DCS Compton              20
# 46         1997       SL  DPMD Jayawardene              17
# 47         1992  ICC/PAK    Inzamam-ul-Haq              15
# 48         1948       WI       FMM Worrell              15
# 49         1911      ENG           CP Mead              17
# 50         2001  ICC/IND          V Sehwag              12
# 53         2004      AUS         MJ Clarke              11
# 55         1929       SA        B Mitchell              20
# 56         1893      ENG    Hon.FS Jackson              12
# 57         2001       SL    TT Samaraweera              12
# 58         1948      AUS         RN Harvey              15
# 59         1965      AUS        KD Walters              16
# 60         2002   ICC/SA          GC Smith              12

# %%
df[df['Career_Length'] > 10 ]['Batting_Strike_Rate'].mean()
# Out:
# np.float64(47.8153488372093)

# %%
value = np.float64(47.8153488372093)

print(round(value, 2))
# Out:
# 47.82

# %%
#players who played before 1960

# %%
df[df['Rookie_year'] < 1960 ]
# Out:
#     Matches_Played  Innings_Batted  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 0               52              80       10  6996                 334  99.94
# 4               22              40        4  2190                 270  60.83
# 6               54              84        9  4555                 194  60.73
# 7               20              31        5  1540                 243  59.23
# 8               82             131       15  6806                 256  58.67
# 9               48              81        5  4455                 207  58.61
# 10              85             140       16  7249                 336  58.45
# 11              93             160       21  8032                 365  57.78
# 14              61             102        7  5410                 211  56.94
# 16              44              74        7  3798                 220  56.68
# 17              79             138       15  6971                 364  56.67
# 20              14              20        2   990                 122  55.00
# 26              34              62        7  2960                 231  53.81
# 34              20              32        5  1394                 201  51.62
# 45              78             131       15  5807                 278  50.06
# 48              51              87        9  3860                 261  49.48
# 49              17              26        2  1185                 182  49.37
# 55              42              80        9  3471                 189  48.88
# 56              20              33        4  1415                 144  48.79
# 58              79             137       10  6149                 205  48.41
# 61              29              48        4  2122                 266  48.22
# 62              39              62        5  2748                 232  48.21
# 64              22              33        6  1296                 127  48.00
#
#     Balls_Faced  Batting_Strike_Rate  100  50   0   4s  6s  final_year  \
# 0          9800                58.60   29  13   7  626   6        1948
# 4           416                56.00   10   5   2  104   1        1954
# 6          6558                34.59   16  23   2  202   6        1935
# 7          1288                45.88    4   7   3  125   4        1939
# 8          4957                42.42   20  35   5  591  27        1968
# 9             0                 0.00   15  19   6  258   2        1958
# 10         7491                38.07   22  24   4  419  27        1947
# 11         4063                53.58   26  30  12  593  32        1974
# 14         5363                46.22   15  28   4  276   8        1930
# 16            0                 0.00   15  14   1  107  11        1960
# 17         2844                39.34   19  33   5  358   7        1955
# 20          178                29.21    3   6   2   37   2        1929
# 26          108                63.88    9  14   3  115   6        1951
# 34         2035                44.86    3   9   1  102   3        1929
# 45         2731                38.81   17  28  10  342   3        1957
# 48          488                40.16    9  22  11  240  11        1963
# 49          619                30.04    4   3   3   38   0        1928
# 55          158                29.11    8  21   3   41   1        1949
# 56            0                 0.00    5   6   3   51   0        1905
# 58         1799                43.74   21  24   7  427   1        1963
# 61         3118                44.77    7   6   1  119   0        1934
# 62         3217                60.02    6  13   4  241   5        1938
# 64         2110                25.59    1  10   2   53   0        1934
#
#     Rookie_year Country      Player_name  Career_Length
# 0          1928     AUS      DG Bradman              20
# 4          1930      WI      GA Headley              24
# 6          1924     ENG     H Sutcliffe              11
# 7          1931     ENG       E Paynter               8
# 8          1955     ENG   KF Barrington              13
# 9          1948      WI       ED Weekes              10
# 10         1927     ENG      WR Hammond              20
# 11         1954      WI       GS Sobers              20
# 14         1908     ENG        JB Hobbs              22
# 16         1948      WI      CL Walcott              12
# 17         1937     ENG        L Hutton              18
# 20         1921     ENG    GE Tyldesley               8
# 26         1935      SA       AD Nourse              16
# 34         1920     AUS         J Ryder               9
# 45         1937     ENG     DCS Compton              20
# 48         1948      WI     FMM Worrell              15
# 49         1911     ENG         CP Mead              17
# 55         1929      SA      B Mitchell              20
# 56         1893     ENG  Hon.FS Jackson              12
# 58         1948     AUS       RN Harvey              15
# 61         1924     AUS     WH Ponsford              10
# 62         1930     AUS       SJ McCabe               8
# 64         1928     ENG      DR Jardine               6

# %%
df[df['Rookie_year'] < 1960 ]['Player_name'].count()
# Out:
# np.int64(23)

# %%
value = np.int64(23)

print(int(value))
# Out:
# 23

# %%
#highest innings score by country

# %%
df.groupby('Country')['Highest_Inns_Score'].max()
# Out:
# Country
# AFG        246
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        248
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_Score, dtype: int64

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('highscorecountry').reset_index().sort_values('highscorecountry', ascending = False)
# Out:
#     Country  highscorecountry
# 6    ICC/WI               400
# 1       AUS               380
# 11       SL               374
# 12       WI               365
# 2       ENG               364
# 4   ICC/PAK               329
# 3   ICC/IND               319
# 9       PAK               313
# 10       SA               278
# 5    ICC/SA               277
# 8        NZ               251
# 7       IND               248
# 0       AFG               246
# 13      ZIM               232
